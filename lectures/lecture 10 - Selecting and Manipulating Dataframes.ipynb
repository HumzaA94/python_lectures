# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
df = pd.read_csv(r"../data/player_stats_by_game.csv")

# %%
df['GAMES STARTED'].unique()
# Out:
# array(['Inactive', '0', 'Did Not Play', '1', 'Did Not Dress',
#        'Not With Team', 'Player Suspended'], dtype=object)

# %%
list_
for c in df.columns:
    val = c.replace(" ","_")
    list_.append(val)
    
df.columns = list_

# %%
df.columns = [c.replace(" ", "_") for c in df.columns]

# %%
# filtering on the data with multiple values for same column
active_players = df[df['GAMES_STARTED'].isin(['0','1'])]

# filtering on the data with single value for one column
# one way
inactive_players = df[df['GAMES_STARTED']=='Inactive']

# second way
did_not_play = df.query("GAMES_STARTED=='Did Not Play'")

# %%
pd.set_option('display.max_columns',100)

# %%
active_players['ASSISTS_AND_POINTS'] = active_players['ASSISTS'] + active_players['POINTS']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
active_players[['PLAYER_NAME','ASSISTS','POINTS','ASSISTS_AND_POINTS']]

# %%
test
# Out:
#                PLAYER_NAME  ASSISTS  POINTS  ASSISTS_AND_POINTS
# 6             Aaron Brooks      0.0     5.0                 5.0
# 21            Aaron Brooks      1.0     2.0                 3.0
# 22            Aaron Brooks      0.0     0.0                 0.0
# 23            Aaron Brooks      0.0     8.0                 8.0
# 24            Aaron Brooks      6.0     4.0                10.0
# ...                    ...      ...     ...                 ...
# 553779  Zydrunas Ilgauskas      0.0     4.0                 4.0
# 553780  Zydrunas Ilgauskas      0.0     0.0                 0.0
# 553789      Zylan Cheatham      1.0     2.0                 3.0
# 553790      Zylan Cheatham      0.0     0.0                 0.0
# 553805      Zylan Cheatham      1.0     2.0                 3.0
#
# [410125 rows x 4 columns]

# %%
did_not_play
# Out:
#                PLAYER_NAME  SEASON_ID   SEASON  SEASON_GAME        DATE  \
# 10            Aaron Brooks         58  2007-08            7  2007-11-11
# 60            Aaron Brooks         58  2007-08           62  2008-03-08
# 62            Aaron Brooks         58  2007-08           64  2008-03-12
# 64            Aaron Brooks         58  2007-08           65  2008-03-14
# 65            Aaron Brooks         58  2007-08           66  2008-03-16
# ...                    ...        ...      ...          ...         ...
# 553741  Zydrunas Ilgauskas         61  2010-11           60  2011-02-27
# 553804      Zylan Cheatham         70  2019-20           42  2020-01-16
# 553806      Zylan Cheatham         70  2019-20           40  2020-01-11
# 553814      Zylan Cheatham         70  2019-20           14  2019-11-19
# 553823      Zylan Cheatham         70  2019-20            3  2019-10-26
#
#        PLAYER_AGE,_FEB TEAM HOME_TEAM AWAY_TEAM GAMES_STARTED  ...  \
# 10              22-301  HOU       CHA       HOU  Did Not Play  ...
# 60              23-054  HOU       HOU       NOH  Did Not Play  ...
# 62              23-058  HOU       ATL       HOU  Did Not Play  ...
# 64              23-060  HOU       HOU       CHA  Did Not Play  ...
# 65              23-062  HOU       HOU       LAL  Did Not Play  ...
# ...                ...  ...       ...       ...           ...  ...
# 553741          35-267  MIA       MIA       NYK  Did Not Play  ...
# 553804          24-060  NOP       NOP       UTA  Did Not Play  ...
# 553806          24-055  NOP       BOS       NOP  Did Not Play  ...
# 553814          24-002  NOP       NOP       POR  Did Not Play  ...
# 553823          23-343  NOP       HOU       NOP  Did Not Play  ...
#
#        DEFENSIVE_REBOUNDS  TOTAL_REBOUNDS  ASSISTS  STEALS  BLOCKS  TURNOVERS  \
# 10                    NaN             NaN      NaN     NaN     NaN        NaN
# 60                    NaN             NaN      NaN     NaN     NaN        NaN
# 62                    NaN             NaN      NaN     NaN     NaN        NaN
# 64                    NaN             NaN      NaN     NaN     NaN        NaN
# 65                    NaN             NaN      NaN     NaN     NaN        NaN
# ...                   ...             ...      ...     ...     ...        ...
# 553741                NaN             NaN      NaN     NaN     NaN        NaN
# 553804                NaN             NaN      NaN     NaN     NaN        NaN
# 553806                NaN             NaN      NaN     NaN     NaN        NaN
# 553814                NaN             NaN      NaN     NaN     NaN        NaN
# 553823                NaN             NaN      NaN     NaN     NaN        NaN
#
#         PERSONAL_FOULS  POINTS  GAME_SCORE  PLUS/MINUS
# 10                 NaN     NaN         NaN         NaN
# 60                 NaN     NaN         NaN         NaN
# 62                 NaN     NaN         NaN         NaN
# 64                 NaN     NaN         NaN         NaN
# 65                 NaN     NaN         NaN         NaN
# ...                ...     ...         ...         ...
# 553741             NaN     NaN         NaN         NaN
# 553804             NaN     NaN         NaN         NaN
# 553806             NaN     NaN         NaN         NaN
# 553814             NaN     NaN         NaN         NaN
# 553823             NaN     NaN         NaN         NaN
#
# [56430 rows x 31 columns]

# %%
df = df[df['GAMES STARTED'].isin(['0','1'])]

# %%
player_names = df['PLAYER NAME'].unique()
